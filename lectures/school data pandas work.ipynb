# %%
import pandas as pd
import numpy as np
from pandas import DataFrame, Series

# Set some pandas options
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)
pd.set_option('display.max_rows', 10)

# %%
data = pd.read_csv('data for panda exercise.csv')
data
# Out:
#      Student Code  Degree       Student Name  Mid  Quiz 1  ...    \
# 0    022-14-19987  BS(CS)        Abdul Basit   28     8.0  ...
# 1   022-14-110233  BS(CS)        Adeel Ahmed   17     NaN  ...
# 2   022-14-110585  BS(CS)       Afrah Zareen   18     5.0  ...
# 3    022-14-19718  BS(CS)     Ahmed Ali Raza   14     7.0  ...
# 4   022-14-110648  BS(CS)    Ahsan Ali Vohra   27     7.0  ...
# ..            ...     ...                ...  ...     ...  ...
# 43  022-14-110451  BS(CS)  Syed Faizan Uddin   28     9.0  ...
# 44  022-14-110589  BS(CS)        Syed Sohaib   25     7.0  ...
# 45  022-14-110400  BS(CS)  Syeda Sabika Raza   27     9.0  ...
# 46   022-14-19911  BS(CS)         Usman Khan   25     8.0  ...
# 47  022-14-110219  BS(CS)        Waqar Ahmed   11     9.0  ...
#
#     Best of Assignments  Total Sessional (50)  Final (50)  Total (100)  Grade
# 0                     9                    45        25.0           70      B
# 1                    10                    32        18.0           50      F
# 2                    10                    33        30.0           63      C
# 3                     2                    23        23.0           46      F
# 4                     9                    43        34.0           77      B
# ..                  ...                   ...         ...          ...    ...
# 43                    8                    45        34.0           79      B
# 44                    9                    41        22.0           63      C
# 45                    9                    45        35.0           80      A
# 46                   10                    43        22.0           65      C
# 47                    7                    27        19.0           46      F
#
# [48 rows x 14 columns]

# %%
data.ix[1].index
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# Index(['Student Code', 'Degree', 'Student Name', 'Mid', 'Quiz 1', 'Quiz 2',
#        'Best of Quizzes', 'Assignment 1', 'Assignment 2',
#        'Best of Assignments', 'Total Sessional (50)', 'Final (50)',
#        'Total (100)', 'Grade'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['Student Code', 'Degree', 'Student Name', 'Mid', 'Quiz 1', 'Quiz 2',
#        'Best of Quizzes', 'Assignment 1', 'Assignment 2',
#        'Best of Assignments', 'Total Sessional (50)', 'Final (50)',
#        'Total (100)', 'Grade'],
#       dtype='object')

# %%
data.tail(10)
# Out:
#      Student Code  Degree       Student Name  Mid  Quiz 1  ...    \
# 38  022-14-110229  BS(CS)   Sadaquat Rafique    9     6.0  ...
# 39  022-14-110107  BS(CS)        Sania Iqbal   28     4.0  ...
# 40  022-14-110584  BS(CS)        Sharif Taqi   27     9.0  ...
# 41  022-14-110225  BS(CS)      Shariqa Ahmad   20     7.0  ...
# 42  022-14-110587  BS(CS)      Sumbul Rehman   28     5.0  ...
# 43  022-14-110451  BS(CS)  Syed Faizan Uddin   28     9.0  ...
# 44  022-14-110589  BS(CS)        Syed Sohaib   25     7.0  ...
# 45  022-14-110400  BS(CS)  Syeda Sabika Raza   27     9.0  ...
# 46   022-14-19911  BS(CS)         Usman Khan   25     8.0  ...
# 47  022-14-110219  BS(CS)        Waqar Ahmed   11     9.0  ...
#
#     Best of Assignments  Total Sessional (50)  Final (50)  Total (100)  Grade
# 38                    7                    22        17.0           39      F
# 39                   11                    43        25.0           68      C
# 40                   10                    46        35.0           81      A
# 41                   10                    37        20.0           57      F
# 42                   10                    44        23.0           67      C
# 43                    8                    45        34.0           79      B
# 44                    9                    41        22.0           63      C
# 45                    9                    45        35.0           80      A
# 46                   10                    43        22.0           65      C
# 47                    7                    27        19.0           46      F
#
# [10 rows x 14 columns]

# %%
data.tail()
# Out:
#      Student Code  Degree       Student Name  Mid  Quiz 1  ...    \
# 43  022-14-110451  BS(CS)  Syed Faizan Uddin   28     9.0  ...
# 44  022-14-110589  BS(CS)        Syed Sohaib   25     7.0  ...
# 45  022-14-110400  BS(CS)  Syeda Sabika Raza   27     9.0  ...
# 46   022-14-19911  BS(CS)         Usman Khan   25     8.0  ...
# 47  022-14-110219  BS(CS)        Waqar Ahmed   11     9.0  ...
#
#     Best of Assignments  Total Sessional (50)  Final (50)  Total (100)  Grade
# 43                    8                    45        34.0           79      B
# 44                    9                    41        22.0           63      C
# 45                    9                    45        35.0           80      A
# 46                   10                    43        22.0           65      C
# 47                    7                    27        19.0           46      F
#
# [5 rows x 14 columns]

# %%
data.head()
# Out:
#     Student Code  Degree     Student Name  Mid  Quiz 1  ...    \
# 0   022-14-19987  BS(CS)      Abdul Basit   28     8.0  ...
# 1  022-14-110233  BS(CS)      Adeel Ahmed   17     NaN  ...
# 2  022-14-110585  BS(CS)     Afrah Zareen   18     5.0  ...
# 3   022-14-19718  BS(CS)   Ahmed Ali Raza   14     7.0  ...
# 4  022-14-110648  BS(CS)  Ahsan Ali Vohra   27     7.0  ...
#
#    Best of Assignments  Total Sessional (50)  Final (50)  Total (100)  Grade
# 0                    9                    45        25.0           70      B
# 1                   10                    32        18.0           50      F
# 2                   10                    33        30.0           63      C
# 3                    2                    23        23.0           46      F
# 4                    9                    43        34.0           77      B
#
# [5 rows x 14 columns]

# %%
data.groupby(['Degree']).count()
# Out:
#         Student Code  Student Name  Mid  Quiz 1  Quiz 2  ...    \
# Degree                                                   ...
# BS(CS)            48            48   48      45      45  ...
#
#         Best of Assignments  Total Sessional (50)  Final (50)  Total (100)  \
# Degree
# BS(CS)                   48                    48          47           48
#
#         Grade
# Degree
# BS(CS)     48
#
# [1 rows x 13 columns]

# %%
data.groupby(['Total (100)']).count()
# Out:
#              Student Code  Degree  Student Name  Mid  Quiz 1  ...    \
# Total (100)                                                   ...
# 18                      1       1             1    1       0  ...
# 29                      1       1             1    1       0  ...
# 39                      2       2             2    2       2  ...
# 46                      2       2             2    2       2  ...
# 50                      1       1             1    1       0  ...
# ...                   ...     ...           ...  ...     ...  ...
# 81                      1       1             1    1       1  ...
# 84                      1       1             1    1       1  ...
# 85                      1       1             1    1       1  ...
# 86                      2       2             2    2       2  ...
# 91                      2       2             2    2       2  ...
#
#              Assignment 2  Best of Assignments  Total Sessional (50)  \
# Total (100)
# 18                      0                    1                     1
# 29                      1                    1                     1
# 39                      1                    2                     2
# 46                      2                    2                     2
# 50                      1                    1                     1
# ...                   ...                  ...                   ...
# 81                      1                    1                     1
# 84                      0                    1                     1
# 85                      1                    1                     1
# 86                      2                    2                     2
# 91                      1                    2                     2
#
#              Final (50)  Grade
# Total (100)
# 18                    0      1
# 29                    1      1
# 39                    2      2
# 46                    2      2
# 50                    1      1
# ...                 ...    ...
# 81                    1      1
# 84                    1      1
# 85                    1      1
# 86                    2      2
# 91                    2      2
#
# [30 rows x 13 columns]

# %%
sum(data['Grade'] =='A')
# Out:
# 8

# %%
data[data['Grade']=='B']
# Out:
#      Student Code  Degree           Student Name  Mid  Quiz 1  ...    \
# 0    022-14-19987  BS(CS)            Abdul Basit   28     8.0  ...
# 4   022-14-110648  BS(CS)        Ahsan Ali Vohra   27     7.0  ...
# 5   022-14-110232  BS(CS)            Ameer Hamza   25     9.0  ...
# 6   022-14-110588  BS(CS)          Anas Ali Khan   28     5.0  ...
# 11  022-14-110591  BS(CS)            Habib Ullah   28     8.0  ...
# ..            ...     ...                    ...  ...     ...  ...
# 30  022-14-110401  BS(CS)        Muhammad Shozab   23     8.0  ...
# 31  022-14-110231  BS(CS)  Muhammad Taha Hasnain   27     7.0  ...
# 36  022-14-110582  BS(CS)             Rida Nasim   25     9.0  ...
# 37  022-14-110230  BS(CS)          Sadaf Nosheen   27     9.0  ...
# 43  022-14-110451  BS(CS)      Syed Faizan Uddin   28     9.0  ...
#
#     Best of Assignments  Total Sessional (50)  Final (50)  Total (100)  Grade
# 0                     9                    45        25.0           70      B
# 4                     9                    43        34.0           77      B
# 5                    10                    44        27.0           71      B
# 6                    10                    44        30.0           74      B
# 11                    5                    41        35.0           76      B
# ..                  ...                   ...         ...          ...    ...
# 30                    9                    40        32.0           72      B
# 31                   10                    44        29.0           73      B
# 36                    9                    43        27.0           70      B
# 37                    9                    45        30.0           75      B
# 43                    8                    45        34.0           79      B
#
# [16 rows x 14 columns]

# %%
data.groupby(['Student Name']).count()
# Out:
#                    Student Code  Degree  Mid  Quiz 1  Quiz 2  ...    \
# Student Name                                                  ...
# Abdul Basit                   1       1    1       1       1  ...
# Adeel Ahmed                   1       1    1       0       1  ...
# Afrah Zareen                  1       1    1       1       1  ...
# Ahmed Ali Raza                1       1    1       1       1  ...
# Ahsan Ali Vohra               1       1    1       1       1  ...
# ...                         ...     ...  ...     ...     ...  ...
# Syed Faizan Uddin             1       1    1       1       1  ...
# Syed Sohaib                   1       1    1       1       1  ...
# Syeda Sabika Raza             1       1    1       1       1  ...
# Usman Khan                    1       1    1       1       1  ...
# Waqar Ahmed                   1       1    1       1       1  ...
#
#                    Best of Assignments  Total Sessional (50)  Final (50)  \
# Student Name
# Abdul Basit                          1                     1           1
# Adeel Ahmed                          1                     1           1
# Afrah Zareen                         1                     1           1
# Ahmed Ali Raza                       1                     1           1
# Ahsan Ali Vohra                      1                     1           1
# ...                                ...                   ...         ...
# Syed Faizan Uddin                    1                     1           1
# Syed Sohaib                          1                     1           1
# Syeda Sabika Raza                    1                     1           1
# Usman Khan                           1                     1           1
# Waqar Ahmed                          1                     1           1
#
#                    Total (100)  Grade
# Student Name
# Abdul Basit                  1      1
# Adeel Ahmed                  1      1
# Afrah Zareen                 1      1
# Ahmed Ali Raza               1      1
# Ahsan Ali Vohra              1      1
# ...                        ...    ...
# Syed Faizan Uddin            1      1
# Syed Sohaib                  1      1
# Syeda Sabika Raza            1      1
# Usman Khan                   1      1
# Waqar Ahmed                  1      1
#
# [48 rows x 13 columns]

# %%
data[data.Mid<20]
# Out:
#      Student Code  Degree               Student Name  Mid  Quiz 1  ...    \
# 1   022-14-110233  BS(CS)                Adeel Ahmed   17     NaN  ...
# 2   022-14-110585  BS(CS)               Afrah Zareen   18     5.0  ...
# 3    022-14-19718  BS(CS)             Ahmed Ali Raza   14     7.0  ...
# 8   022-14-110601  BS(CS)             Areesha Sohail   19     9.0  ...
# 15   022-14-19916  BS(CS)               Haseeb Sajid   18     NaN  ...
# 18  022-14-110223  BS(CS)              Madiha Jabeen   16     5.0  ...
# 29  022-14-110217  BS(CS)  Muhammad Shahroz Khurshid   17     7.0  ...
# 32  022-14-110035  BS(CS)      Muhammad Wajahat Khan    9     NaN  ...
# 38  022-14-110229  BS(CS)           Sadaquat Rafique    9     6.0  ...
# 47  022-14-110219  BS(CS)                Waqar Ahmed   11     9.0  ...
#
#     Best of Assignments  Total Sessional (50)  Final (50)  Total (100)  Grade
# 1                    10                    32        18.0           50      F
# 2                    10                    33        30.0           63      C
# 3                     2                    23        23.0           46      F
# 8                     9                    37        24.0           61      C
# 15                    0                    18         NaN           18      F
# 18                   10                    31        29.0           60      C
# 29                    6                    30         9.0           39      F
# 32                   10                    21         8.0           29      F
# 38                    7                    22        17.0           39      F
# 47                    7                    27        19.0           46      F
#
# [10 rows x 14 columns]

# %%
data[data['Mid']>27]
# Out:
#      Student Code  Degree         Student Name  Mid  Quiz 1  ...    \
# 0    022-14-19987  BS(CS)          Abdul Basit   28     8.0  ...
# 6   022-14-110588  BS(CS)        Anas Ali Khan   28     5.0  ...
# 9   022-14-110599  BS(CS)              Arsalan   28     8.0  ...
# 10  022-14-110214  BS(CS)  Fatima Haider Warsi   30     8.0  ...
# 11  022-14-110591  BS(CS)          Habib Ullah   28     8.0  ...
# 24  022-14-110215  BS(CS)       Muhammad Bilal   28     5.0  ...
# 39  022-14-110107  BS(CS)          Sania Iqbal   28     4.0  ...
# 42  022-14-110587  BS(CS)        Sumbul Rehman   28     5.0  ...
# 43  022-14-110451  BS(CS)    Syed Faizan Uddin   28     9.0  ...
#
#     Best of Assignments  Total Sessional (50)  Final (50)  Total (100)  Grade
# 0                     9                    45        25.0           70      B
# 6                    10                    44        30.0           74      B
# 9                     8                    44        40.0           84      A
# 10                    8                    46        45.0           91      A
# 11                    5                    41        35.0           76      B
# 24                   11                    44        33.0           77      B
# 39                   11                    43        25.0           68      C
# 42                   10                    44        23.0           67      C
# 43                    8                    45        34.0           79      B
#
# [9 rows x 14 columns]

# %%
data.iloc[5]
# Out:
# Student Code            022-14-110232
# Degree                         BS(CS)
# Student Name              Ameer Hamza
# Mid                                25
# Quiz 1                              9
#                             ...
# Best of Assignments                10
# Total Sessional (50)               44
# Final (50)                         27
# Total (100)                        71
# Grade                               B
# Name: 5, Length: 14, dtype: object

# %%
data.loc[6]
# Out:
# Student_Code            022-14-110588
# Degree                         BS(CS)
# Student_Name            Anas Ali Khan
# Mid                                28
# Quiz_1                              5
# Quiz_2                              6
# Best_of_Quizzes                     6
# Assignment_1                        8
# Assignment_2                       10
# Best_of_Assignments                10
# Total_Sessional_(50)               44
# Final (50)                         30
# Total (100)                        74
# Grade                               B
# Name: 6, dtype: object

# %%
data[data['Student Name'] == 'Madiha Jabeen']
# Out:
#      Student Code  Degree   Student Name  Mid  Quiz 1  ...    \
# 18  022-14-110223  BS(CS)  Madiha Jabeen   16     5.0  ...
#
#     Best of Assignments  Total Sessional (50)  Final (50)  Total (100)  Grade
# 18                   10                    31        29.0           60      C
#
# [1 rows x 14 columns]

# %%
data['Assignment 2'][3:8]
# Out:
# 3     2.0
# 4     9.0
# 5    10.0
# 6    10.0
# 7    10.0
# Name: Assignment 2, dtype: float64

# %%
data.iloc[[1, 3, 5 , 7 , 8 , 10 , 14]]['Best of Quizzes']
# Out:
# 1     5
# 3     7
# 5     9
# 7     9
# 8     9
# 10    8
# 14    7
# Name: Best of Quizzes, dtype: int64

# %%
data.iloc[[2,4,5,6,7,8,9,0,3,1]].Assignment_2
# Out:
# 2    10.0
# 4     9.0
# 5    10.0
# 6    10.0
# 7    10.0
# 8     9.0
# 9     NaN
# 0     9.0
# 3     2.0
# 1    10.0
# Name: Assignment_2, dtype: float64

# %%
data1 = data.loc[:, "Student Code":"Grade"]
data1.head()
# Out:
#     Student Code  Degree     Student Name  Mid  Quiz 1  ...    \
# 0   022-14-19987  BS(CS)      Abdul Basit   28     8.0  ...
# 1  022-14-110233  BS(CS)      Adeel Ahmed   17     NaN  ...
# 2  022-14-110585  BS(CS)     Afrah Zareen   18     5.0  ...
# 3   022-14-19718  BS(CS)   Ahmed Ali Raza   14     7.0  ...
# 4  022-14-110648  BS(CS)  Ahsan Ali Vohra   27     7.0  ...
#
#    Best of Assignments  Total Sessional (50)  Final (50)  Total (100)  Grade
# 0                    9                    45        25.0           70      B
# 1                   10                    32        18.0           50      F
# 2                   10                    33        30.0           63      C
# 3                    2                    23        23.0           46      F
# 4                    9                    43        34.0           77      B
#
# [5 rows x 14 columns]

# %%
print(data.shape)
# Out:
# (48, 14)

# %%
del data['Assignment 1']
data.head()
# Out:
#     Student Code  Degree     Student Name  Mid  Quiz 1  ...    \
# 0   022-14-19987  BS(CS)      Abdul Basit   28     8.0  ...
# 1  022-14-110233  BS(CS)      Adeel Ahmed   17     NaN  ...
# 2  022-14-110585  BS(CS)     Afrah Zareen   18     5.0  ...
# 3   022-14-19718  BS(CS)   Ahmed Ali Raza   14     7.0  ...
# 4  022-14-110648  BS(CS)  Ahsan Ali Vohra   27     7.0  ...
#
#    Best of Assignments  Total Sessional (50)  Final (50)  Total (100)  Grade
# 0                    9                    45        25.0           70      B
# 1                   10                    32        18.0           50      F
# 2                   10                    33        30.0           63      C
# 3                    2                    23        23.0           46      F
# 4                    9                    43        34.0           77      B
#
# [5 rows x 13 columns]

# %%
data.iloc[0:3 ,:] = np.nan
data.head()
# Out:
#     Student Code  Degree     Student Name   Mid  Quiz 1  ...    \
# 0            NaN     NaN              NaN   NaN     NaN  ...
# 1            NaN     NaN              NaN   NaN     NaN  ...
# 2            NaN     NaN              NaN   NaN     NaN  ...
# 3   022-14-19718  BS(CS)   Ahmed Ali Raza  14.0     7.0  ...
# 4  022-14-110648  BS(CS)  Ahsan Ali Vohra  27.0     7.0  ...
#
#    Best of Assignments  Total Sessional (50)  Final (50)  Total (100)  Grade
# 0                  NaN                   NaN         NaN          NaN    NaN
# 1                  NaN                   NaN         NaN          NaN    NaN
# 2                  NaN                   NaN         NaN          NaN    NaN
# 3                  2.0                  23.0        23.0         46.0      F
# 4                  9.0                  43.0        34.0         77.0      B
#
# [5 rows x 13 columns]

# %%
data = data.dropna(how='any')
data.head()
# Out:
#     Student Code  Degree      Student Name   Mid  Quiz 1  ...    \
# 3   022-14-19718  BS(CS)    Ahmed Ali Raza  14.0     7.0  ...
# 4  022-14-110648  BS(CS)   Ahsan Ali Vohra  27.0     7.0  ...
# 5  022-14-110232  BS(CS)       Ameer Hamza  25.0     9.0  ...
# 6  022-14-110588  BS(CS)     Anas Ali Khan  28.0     5.0  ...
# 7  022-14-110388  BS(CS)  Aneebullah Niazi  26.0     9.0  ...
#
#    Best of Assignments  Total Sessional (50)  Final (50)  Total (100)  Grade
# 3                  2.0                  23.0        23.0         46.0      F
# 4                  9.0                  43.0        34.0         77.0      B
# 5                 10.0                  44.0        27.0         71.0      B
# 6                 10.0                  44.0        30.0         74.0      B
# 7                 10.0                  45.0        40.0         85.0      A
#
# [5 rows x 13 columns]

# %%
data.shape
# Out:
# (30, 13)

# %%
data[(data['Student Name'].str.contains('Ali')) & (data['Grade'] == 'B')]
# Out:
#     Student Code  Degree     Student Name   Mid  Quiz 1  ...    \
# 4  022-14-110648  BS(CS)  Ahsan Ali Vohra  27.0     7.0  ...
# 6  022-14-110588  BS(CS)    Anas Ali Khan  28.0     5.0  ...
#
#    Best of Assignments  Total Sessional (50)  Final (50)  Total (100)  Grade
# 4                  9.0                  43.0        34.0         77.0      B
# 6                 10.0                  44.0        30.0         74.0      B
#
# [2 rows x 13 columns]

# %%
data.groupby('Grade').count()
# Out:
#        Student_Code  Degree  Student_Name  Mid  Quiz_1  Quiz_2  \
# Grade
# A                 8       8             8    8       8       8
# B                16      16            16   16      16      16
# C                13      13            13   13      13      11
# F                11      11            11   11       8      10
#
#        Best_of_Quizzes  Assignment_1  Assignment_2  Best_of_Assignments  \
# Grade
# A                    8             8             5                    8
# B                   16            16            11                   16
# C                   13            12            12                   13
# F                   11             9             8                   11
#
#        Total_Sessional_(50)  Final (50)  Total (100)
# Grade
# A                         8           8            8
# B                        16          16           16
# C                        13          13           13
# F                        11          10           11

# %%
data[['Student Name','Mid', 'Grade']][(data.Grade == 'A')]
# Out:
#         Student Name   Mid Grade
# 7   Aneebullah Niazi  26.0     A
# 19   Mohammad Hunain  27.0     A
# 25    Muhammad Faraz  26.0     A
# 34  Nazeer Bin Zafar  25.0     A
# 40       Sharif Taqi  27.0     A

# %%
data[(data.Best_of_Quizzes == 9) & (data.Grade == 'A')]
# Out:
#      Student_Code  Degree       Student_Name  Mid  Quiz_1  Quiz_2  \
# 7   022-14-110388  BS(CS)   Aneebullah Niazi   26     9.0     6.0
# 19  022-14-110222  BS(CS)    Mohammad Hunain   27     9.0     6.0
# 25  022-14-110105  BS(CS)     Muhammad Faraz   26     9.0     6.0
# 34  022-14-110413  BS(CS)   Nazeer Bin Zafar   25     9.0     6.0
# 40  022-14-110584  BS(CS)        Sharif Taqi   27     9.0     6.0
# 45  022-14-110400  BS(CS)  Syeda Sabika Raza   27     9.0     6.0
#
#     Best_of_Quizzes  Assignment_1  Assignment_2  Best_of_Assignments  \
# 7                 9           8.0          10.0                   10
# 19                9           8.0          10.0                   10
# 25                9           8.0          10.0                   10
# 34                9           8.0          10.0                   10
# 40                9           8.0          10.0                   10
# 45                9           9.0           NaN                    9
#
#     Total_Sessional_(50)  Final (50)  Total (100) Grade
# 7                     45        40.0           85     A
# 19                    46        45.0           91     A
# 25                    45        41.0           86     A
# 34                    44        42.0           86     A
# 40                    46        35.0           81     A
# 45                    45        35.0           80     A

# %%
data[data.Student_Name.str.contains(' Ali ')]
# Out:
#     Student_Code  Degree     Student_Name   Mid  Quiz_1  Quiz_2  \
# 3   022-14-19718  BS(CS)   Ahmed Ali Raza  14.0     7.0     2.0
# 4  022-14-110648  BS(CS)  Ahsan Ali Vohra  27.0     7.0     6.0
# 6  022-14-110588  BS(CS)    Anas Ali Khan  28.0     5.0     6.0
#
#    Best_of_Quizzes  Assignment_2  Best_of_Assignments  Total_Sessional_(50)  \
# 3              7.0           2.0                  2.0                  23.0
# 4              7.0           9.0                  9.0                  43.0
# 6              6.0          10.0                 10.0                  44.0
#
#    Final (50)  Total (100) Grade
# 3        23.0         46.0     F
# 4        34.0         77.0     B
# 6        30.0         74.0     B

# %%
data[data.Student_Name.str.endswith('Hamza')]
# Out:
#     Student_Code  Degree Student_Name   Mid  Quiz_1  Quiz_2  Best_of_Quizzes  \
# 5  022-14-110232  BS(CS)  Ameer Hamza  25.0     9.0     6.0              9.0
#
#    Assignment_2  Best_of_Assignments  Total_Sessional_(50)  Final (50)  \
# 5          10.0                 10.0                  44.0        27.0
#
#    Total (100) Grade
# 5         71.0     B

# %%
persons = pd.DataFrame({
    'name': ['Shahzad' , 'Taha' , 'Fatima' , 'Khani' , 'Samia'],
    'age': np.random.randint(1,40, size = [5]),
    'percent': np.random.randint(40,90, size = [5])
    
})

# %%
persons
# Out:
#       name  age  percent
# 0  Shahzad   14       77
# 1     Taha   20       43
# 2   Fatima   22       81
# 3    Khani   18       42
# 4    Samia   28       83

# %%
def a(age):
    if age < 18:
        return 'Non-Adult'
    else:
        return 'Adult'

# %%
persons['age'].map(a) #We can use 'apply' also
# Out:
# 0    Non-Adult
# 1        Adult
# 2        Adult
# 3        Adult
# 4        Adult
# Name: age, dtype: object

# %%
persons
# Out:
#       name  age  percent     Status
# 0  Shahzad   14       77  Non-Adult
# 1     Taha   20       43      Adult
# 2   Fatima   22       81      Adult
# 3    Khani   18       42      Adult
# 4    Samia   28       83      Adult
